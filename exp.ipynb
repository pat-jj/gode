# %%
import os
import math
import copy
import pickle

import numpy as np
import pandas as pd
from tqdm.auto import tqdm
import dgl

from dataset_construction.utils import preprocess_kg, create_split, process_disease_area_split, create_dgl_graph, evaluate_graph_construct, convert2str, data_download_wrapper

import warnings
warnings.filterwarnings("ignore")

# %%
kg_dir = '/data/pj20/txgnn/kg/'

df = pd.read_csv(kg_dir + 'kg.csv')
df = df[['x_type', 'x_id', 'relation', 'y_type', 'y_id']]

# %%
unique_relation = np.unique(df.relation.values)
unique_relation
# Out:
# array(['anatomy_anatomy', 'anatomy_protein_absent',
#        'anatomy_protein_present', 'bioprocess_bioprocess',
#        'bioprocess_protein', 'cellcomp_cellcomp', 'cellcomp_protein',
#        'contraindication', 'disease_disease',
#        'disease_phenotype_negative', 'disease_phenotype_positive',
#        'disease_protein', 'drug_drug', 'drug_effect', 'drug_protein',
#        'exposure_bioprocess', 'exposure_cellcomp', 'exposure_disease',
#        'exposure_exposure', 'exposure_molfunc', 'exposure_protein',
#        'indication', 'molfunc_molfunc', 'molfunc_protein',
#        'off-label use', 'pathway_pathway', 'pathway_protein',
#        'phenotype_phenotype', 'phenotype_protein', 'protein_protein'],
#       dtype=object)

# %%
undirected_index = []

for i in tqdm(unique_relation):
    if ('_' in i) and (i.split('_')[0] == i.split('_')[1]):
        # homogeneous graph
        df_temp = df[df.relation == i]
        df_temp['check_string'] = df_temp.apply(lambda row: '_'.join(sorted([str(row['x_id']), str(row['y_id'])])), axis=1)
        undirected_index.append(df_temp.drop_duplicates('check_string').index.values.tolist())
    else:
        # undirected, 去重 (a->b 和 b->a 只记其中一个)
        d_off = df[df.relation == i]
        undirected_index.append(d_off[d_off.x_type == d_off.x_type.iloc[0]].index.values.tolist())
# Out:
# 100%|██████████| 30/30 [00:32<00:00,  1.08s/it]

# %%
flat_list = [item for sublist in undirected_index for item in sublist]
df = df[df.index.isin(flat_list)]
unique_node_types = np.unique(np.append(np.unique(df.x_type.values), np.unique(df.y_type.values)))

# %%
unique_node_types
# Out:
# array(['anatomy', 'biological_process', 'cellular_component', 'disease',
#        'drug', 'effect/phenotype', 'exposure', 'gene/protein',
#        'molecular_function', 'pathway'], dtype=object)

# %%
df
# Out:
#                x_type              x_id  ... x_idx y_idx
# 0        gene/protein            9796.0  ...   NaN   NaN
# 1        gene/protein            7918.0  ...   NaN   NaN
# 2        gene/protein            8233.0  ...   NaN   NaN
# 3        gene/protein            4899.0  ...   NaN   NaN
# 4        gene/protein            5297.0  ...   NaN   NaN
# ...               ...               ...  ...   ...   ...
# 5949711       disease           16982.0  ...   NaN   NaN
# 5949712       disease  19314_19023_2726  ...   NaN   NaN
# 5949713       disease  19314_19023_2726  ...   NaN   NaN
# 5949714       disease            4747.0  ...   NaN   NaN
# 5949715       disease            5297.0  ...   NaN   NaN
#
# [4050249 rows x 7 columns]

# %%
df['x_idx'] = np.nan
df['y_idx'] = np.nan
df['x_id'] = df.x_id.apply(lambda x: convert2str(x))
df['y_id'] = df.y_id.apply(lambda x: convert2str(x))

# %%
idx_map = {}
for i in tqdm(unique_node_types):
    names = np.unique(np.append(df[df.x_type == i]['x_id'].values, df[df.y_type == i]['y_id'].values))
    names2idx = dict(zip(names, list(range(len(names)))))
    df.loc[df.x_type == i, 'x_idx'] = df[df.x_type == i]['x_id'].apply(lambda x: names2idx[x])
    df.loc[df.y_type == i, 'y_idx'] = df[df.y_type == i]['y_id'].apply(lambda x: names2idx[x])
    idx_map[i] = names2idx
# Out:
# 100%|██████████| 10/10 [00:18<00:00,  1.87s/it]

# %%
df_test = df[df.x_type == "gene/protein"]
df_test = df_test[df_test.x_idx == 1.0]

# %%
df_test
# Out:
#                x_type  x_id                 relation  ...     y_id x_idx    y_idx
# 21007    gene/protein  10.0          protein_protein  ...   8493.0   1.0  25662.0
# 25217    gene/protein  10.0          protein_protein  ...   6790.0   1.0  22307.0
# 39248    gene/protein  10.0          protein_protein  ...   6794.0   1.0  22310.0
# 49356    gene/protein  10.0          protein_protein  ...   8930.0   1.0  26207.0
# 50145    gene/protein  10.0          protein_protein  ...  25818.0   1.0  10753.0
# ...               ...   ...                      ...  ...      ...   ...      ...
# 4706870  gene/protein  10.0  anatomy_protein_present  ...   2108.0   1.0   5872.0
# 4706871  gene/protein  10.0  anatomy_protein_present  ...   2113.0   1.0   5878.0
# 4706872  gene/protein  10.0  anatomy_protein_present  ...   2114.0   1.0   5879.0
# 5376898  gene/protein  10.0   anatomy_protein_absent  ...   1377.0   1.0   2220.0
# 5376899  gene/protein  10.0   anatomy_protein_absent  ...   1379.0   1.0   2230.0
#
# [93 rows x 7 columns]

# %%
df_train = pd.read_csv('/data/pj20/txgnn/kg/full_graph_42/train.csv')
df_valid = pd.read_csv('/data/pj20/txgnn/kg/full_graph_42/valid.csv')
df_test = pd.read_csv('/data/pj20/txgnn/kg/full_graph_42/test.csv')

# %%
## create_dgl_graph
unique_graph = df_train[['x_type', 'relation', 'y_type']].drop_duplicates()
unique_graph
# Out:
#                      x_type                        relation              y_type
# 0              gene/protein                 protein_protein        gene/protein
# 305021                 drug                    drug_protein        gene/protein
# 329391                 drug                contraindication             disease
# 358532                 drug                      indication             disease
# 367451                 drug                   off-label use             disease
# 369891                 drug                       drug_drug                drug
# 1639389        gene/protein               phenotype_protein    effect/phenotype
# 1642553    effect/phenotype             phenotype_phenotype    effect/phenotype
# 1660352             disease      disease_phenotype_negative    effect/phenotype
# 1661485             disease      disease_phenotype_positive    effect/phenotype
# 1804286        gene/protein                 disease_protein             disease
# 1880676             disease                 disease_disease             disease
# 1911260                drug                     drug_effect    effect/phenotype
# 1972805  biological_process           bioprocess_bioprocess  biological_process
# 2023047  molecular_function                 molfunc_molfunc  molecular_function
# 2035942  cellular_component               cellcomp_cellcomp  cellular_component
# 2040545        gene/protein                 molfunc_protein  molecular_function
# 2106599        gene/protein                cellcomp_protein  cellular_component
# 2185831        gene/protein              bioprocess_protein  biological_process
# 2323396            exposure                exposure_protein        gene/protein
# 2324547            exposure                exposure_disease             disease
# 2326736            exposure               exposure_exposure            exposure
# 2328702            exposure             exposure_bioprocess  biological_process
# 2330246            exposure                exposure_molfunc  molecular_function
# 2330289            exposure               exposure_cellcomp  cellular_component
# 2330299             pathway                 pathway_pathway             pathway
# 2332707        gene/protein                 pathway_protein             pathway
# 2373221             anatomy                 anatomy_anatomy             anatomy
# 2386551        gene/protein         anatomy_protein_present             anatomy
# 3828844        gene/protein          anatomy_protein_absent             anatomy
# 4152758        gene/protein                rev_drug_protein                drug
# 4177128             disease            rev_contraindication                drug
# 4206269             disease                  rev_indication                drug
# 4215188             disease               rev_off-label use                drug
# 5487126    effect/phenotype           rev_phenotype_protein        gene/protein
# 5508089    effect/phenotype  rev_disease_phenotype_negative             disease
# 5509222    effect/phenotype  rev_disease_phenotype_positive             disease
# 5652023             disease             rev_disease_protein        gene/protein
# 5758997    effect/phenotype                 rev_drug_effect                drug
# 5888282  molecular_function             rev_molfunc_protein        gene/protein
# 5954336  cellular_component            rev_cellcomp_protein        gene/protein
# 6033568  biological_process          rev_bioprocess_protein        gene/protein
# 6171133        gene/protein            rev_exposure_protein            exposure
# 6172284             disease            rev_exposure_disease            exposure
# 6176439  biological_process         rev_exposure_bioprocess            exposure
# 6177983  molecular_function            rev_exposure_molfunc            exposure
# 6178026  cellular_component           rev_exposure_cellcomp            exposure
# 6180444             pathway             rev_pathway_protein        gene/protein
# 6234288             anatomy     rev_anatomy_protein_present        gene/protein
# 7676581             anatomy      rev_anatomy_protein_absent        gene/protein

# %%
DGL_input = {}
for i in unique_graph.values:
    o = df_train[df_train.relation == i[1]][['x_idx', 'y_idx']].values.T
    DGL_input[tuple(i)] = (o[0].astype(int), o[1].astype(int))

# %%
temp = dict(df.groupby('x_type')['x_idx'].max())
temp2 = dict(df.groupby('y_type')['y_idx'].max())
temp['effect/phenotype'] = 0.0

output = {}
for d in (temp, temp2):
    for k, v in d.items():
        output.setdefault(k, float('-inf'))
        output[k] = max(output[k], v)

# %%
DGL_input
# Out:
# {('gene/protein',
#   'protein_protein',
#   'gene/protein'): (array([27422, 23886, 24822, ..., 23283, 18775,  7948]), array([19536, 26764, 10205, ...,  8412, 15799, 25835])),
#  ('drug',
#   'drug_protein',
#   'gene/protein'): (array([5810, 5810, 5819, ..., 7705, 6020, 6020]), array([ 9202,  9200, 13100, ..., 18963, 14238, 14254])),
#  ('drug',
#   'contraindication',
#   'disease'): (array([3448, 3448, 7534, ...,   73,  335, 1178]), array([12675,  1569, 12675, ..., 10809,   311,  1484])),
#  ('drug',
#   'indication',
#   'disease'): (array([ 478,  478, 6458, ...,   34,   34,  948]), array([12675,  1569, 12675, ...,  8492, 16381, 14069])),
#  ('drug',
#   'off-label use',
#   'disease'): (array([884, 884, 868, ..., 396, 396, 187]), array([12675,  1569, 12675, ..., 14964,  2546,  2546])),
#  ('drug',
#   'drug_drug',
#   'drug'): (array([   0,    4,    5, ..., 5797, 5797, 5797]), array([3979, 3979, 3979, ..., 2642, 6960, 7627])),
#  ('gene/protein',
#   'phenotype_protein',
#   'effect/phenotype'): (array([    0,  8793,  9181, ...,  6217,  6869, 13895]), array([ 4750,  4750,  4750, ...,  4621,  3893, 11187])),
#  ('effect/phenotype',
#   'phenotype_phenotype',
#   'effect/phenotype'): (array([3941, 1567,    0, ..., 5943, 5944, 5944]), array([ 4296,  5865, 11685, ...,  7755,  3845,  7755])),
#  ('disease',
#   'disease_phenotype_negative',
#   'effect/phenotype'): (array([ 2502,  2502,  1038, ...,   327, 14797, 15584]), array([9940, 3351, 4101, ..., 9948, 4243, 1987])),
#  ('disease',
#   'disease_phenotype_positive',
#   'effect/phenotype'): (array([ 2182,  2502,  2502, ...,  6562, 12414, 12891]), array([11966, 11187,  9804, ...,   523,  4558, 13759])),
#  ('gene/protein',
#   'disease_protein',
#   'disease'): (array([    0,  8739, 16011, ..., 10174, 19045, 20233]), array([12715, 12715, 12715, ..., 15146, 12967, 16527])),
#  ('disease',
#   'disease_disease',
#   'disease'): (array([ 9775,  7816,  8488, ..., 13936, 10860,  9955]), array([11198, 12639, 16191, ..., 13876,  9562,  9562])),
#  ('drug',
#   'drug_effect',
#   'effect/phenotype'): (array([567, 567, 567, ...,  95,  95,  95]), array([ 4585, 11250, 13398, ...,  4046,  3490,  5718])),
#  ('biological_process',
#   'bioprocess_bioprocess',
#   'biological_process'): (array([20521, 16936, 20550, ..., 11041, 27979, 19121]), array([20551, 20551, 20551, ..., 11043, 25482, 19118])),
#  ('molecular_function',
#   'molfunc_molfunc',
#   'molecular_function'): (array([10210, 10210, 10210, ...,  3406,  9009,  4211]), array([  135,   922,   597, ...,  1576, 10025,  7384])),
#  ('cellular_component',
#   'cellcomp_cellcomp',
#   'cellular_component'): (array([  82,   82,   82, ..., 3321, 3973, 1423]), array([3416, 2830,  877, ..., 3319, 4062, 3468])),
#  ('gene/protein',
#   'molfunc_protein',
#   'molecular_function'): (array([ 8903, 14127, 23730, ..., 23277, 23456,   464]), array([3493, 3493, 3493, ..., 7518, 2116, 8483])),
#  ('gene/protein',
#   'cellcomp_protein',
#   'cellular_component'): (array([    0, 16597,  8641, ..., 14608, 14708,   662]), array([ 480,  480,  480, ...,   35, 1189, 2542])),
#  ('gene/protein',
#   'bioprocess_protein',
#   'biological_process'): (array([    0,  6403, 10924, ...,  1590,  1670,  3160]), array([16964, 16964, 16964, ..., 20464, 26770,  3219])),
#  ('exposure',
#   'exposure_protein',
#   'gene/protein'): (array([314, 210, 210, ..., 747, 747, 747]), array([ 7262,  9190, 20727, ..., 16373, 19796, 15777])),
#  ('exposure',
#   'exposure_disease',
#   'disease'): (array([152, 113, 113, ..., 745, 745, 746]), array([ 2026, 12697,  2026, ..., 12766,   742, 17060])),
#  ('exposure',
#   'exposure_exposure',
#   'exposure'): (array([179, 370, 370, ..., 531, 615,  20]), array([174, 182, 310, ..., 741, 741, 741])),
#  ('exposure',
#   'exposure_bioprocess',
#   'biological_process'): (array([260, 341, 268, ..., 738, 738, 740]), array([26475, 26475, 26475, ..., 26249, 12310, 12184])),
#  ('exposure',
#   'exposure_molfunc',
#   'molecular_function'): (array([101, 502, 263, 435,  55, 519,  88, 593, 618, 656, 648, 722, 406,
#          638, 663, 664, 407, 648, 407, 648, 717, 435,  51, 435, 146, 445,
#          656,  51, 205, 223, 385, 143, 788, 777, 568, 629, 583, 601, 776,
#          648, 648, 648, 648]), array([ 3273,  3273,  5701,  5701,  5701,  5701,  5701,  5701,  5701,
#           5701,  5701,  5701,  5413,  5413,  5413,  5413,  5694,  5694,
#           7759,  7759,  7759,  5637,  5637, 10386,  5600,  5600,  5600,
#           6385,  5622,  5622,  5622,  5622,  5622,  3593,  3593,  3593,
#          10155,  6734,  6085,  6085,  5725,  6651,  6082])),
#  ('exposure',
#   'exposure_cellcomp',
#   'cellular_component'): (array([406, 664, 407, 801, 133, 223, 339, 297, 143, 801]), array([3258, 3258, 3030, 3030, 3251, 3251, 3251, 3251, 3251, 2436])),
#  ('pathway',
#   'pathway_pathway',
#   'pathway'): (array([   1,    1,    1, ...,  779, 2210, 2515]), array([   3,  378, 1270, ..., 2513, 2513, 2514])),
#  ('gene/protein',
#   'pathway_protein',
#   'pathway'): (array([    0,     0,     1, ..., 27609, 27609, 27609]), array([  69, 1663,  208, ..., 1459, 1626, 2475])),
#  ('anatomy',
#   'anatomy_anatomy',
#   'anatomy'): (array([4250, 7077, 9572, ..., 8371, 8371, 3196]), array([11178,  3163,   282, ..., 13256, 13257, 13258])),
#  ('gene/protein',
#   'anatomy_protein_present',
#   'anatomy'): (array([22750, 22750, 22750, ..., 19576, 19576, 19576]), array([ 4250, 11792, 12682, ...,  5764,  5878,  6300])),
#  ('gene/protein',
#   'anatomy_protein_absent',
#   'anatomy'): (array([ 9560,  9560, 13132, ...,  4002,  4002,  4002]), array([ 2599, 10735, 10735, ...,  2230,  5804, 11370])),
#  ('gene/protein',
#   'rev_drug_protein',
#   'drug'): (array([ 9202,  9200, 13100, ..., 18963, 14238, 14254]), array([5810, 5810, 5819, ..., 7705, 6020, 6020])),
#  ('disease',
#   'rev_contraindication',
#   'drug'): (array([12675,  1569, 12675, ..., 10809,   311,  1484]), array([3448, 3448, 7534, ...,   73,  335, 1178])),
#  ('disease',
#   'rev_indication',
#   'drug'): (array([12675,  1569, 12675, ...,  8492, 16381, 14069]), array([ 478,  478, 6458, ...,   34,   34,  948])),
#  ('disease',
#   'rev_off-label use',
#   'drug'): (array([12675,  1569, 12675, ..., 14964,  2546,  2546]), array([884, 884, 868, ..., 396, 396, 187])),
#  ('effect/phenotype',
#   'rev_phenotype_protein',
#   'gene/protein'): (array([ 4750,  4750,  4750, ...,  4621,  3893, 11187]), array([    0,  8793,  9181, ...,  6217,  6869, 13895])),
#  ('effect/phenotype',
#   'rev_disease_phenotype_negative',
#   'disease'): (array([9940, 3351, 4101, ..., 9948, 4243, 1987]), array([ 2502,  2502,  1038, ...,   327, 14797, 15584])),
#  ('effect/phenotype',
#   'rev_disease_phenotype_positive',
#   'disease'): (array([11966, 11187,  9804, ...,   523,  4558, 13759]), array([ 2182,  2502,  2502, ...,  6562, 12414, 12891])),
#  ('disease',
#   'rev_disease_protein',
#   'gene/protein'): (array([12715, 12715, 12715, ..., 15146, 12967, 16527]), array([    0,  8739, 16011, ..., 10174, 19045, 20233])),
#  ('effect/phenotype',
#   'rev_drug_effect',
#   'drug'): (array([ 4585, 11250, 13398, ...,  4046,  3490,  5718]), array([567, 567, 567, ...,  95,  95,  95])),
#  ('molecular_function',
#   'rev_molfunc_protein',
#   'gene/protein'): (array([3493, 3493, 3493, ..., 7518, 2116, 8483]), array([ 8903, 14127, 23730, ..., 23277, 23456,   464])),
#  ('cellular_component',
#   'rev_cellcomp_protein',
#   'gene/protein'): (array([ 480,  480,  480, ...,   35, 1189, 2542]), array([    0, 16597,  8641, ..., 14608, 14708,   662])),
#  ('biological_process',
#   'rev_bioprocess_protein',
#   'gene/protein'): (array([16964, 16964, 16964, ..., 20464, 26770,  3219]), array([    0,  6403, 10924, ...,  1590,  1670,  3160])),
#  ('gene/protein',
#   'rev_exposure_protein',
#   'exposure'): (array([ 7262,  9190, 20727, ..., 16373, 19796, 15777]), array([314, 210, 210, ..., 747, 747, 747])),
#  ('disease',
#   'rev_exposure_disease',
#   'exposure'): (array([ 2026, 12697,  2026, ..., 12766,   742, 17060]), array([152, 113, 113, ..., 745, 745, 746])),
#  ('biological_process',
#   'rev_exposure_bioprocess',
#   'exposure'): (array([26475, 26475, 26475, ..., 26249, 12310, 12184]), array([260, 341, 268, ..., 738, 738, 740])),
#  ('molecular_function',
#   'rev_exposure_molfunc',
#   'exposure'): (array([ 3273,  3273,  5701,  5701,  5701,  5701,  5701,  5701,  5701,
#           5701,  5701,  5701,  5413,  5413,  5413,  5413,  5694,  5694,
#           7759,  7759,  7759,  5637,  5637, 10386,  5600,  5600,  5600,
#           6385,  5622,  5622,  5622,  5622,  5622,  3593,  3593,  3593,
#          10155,  6734,  6085,  6085,  5725,  6651,  6082]), array([101, 502, 263, 435,  55, 519,  88, 593, 618, 656, 648, 722, 406,
#          638, 663, 664, 407, 648, 407, 648, 717, 435,  51, 435, 146, 445,
#          656,  51, 205, 223, 385, 143, 788, 777, 568, 629, 583, 601, 776,
#          648, 648, 648, 648])),
#  ('cellular_component',
#   'rev_exposure_cellcomp',
#   'exposure'): (array([3258, 3258, 3030, 3030, 3251, 3251, 3251, 3251, 3251, 2436]), array([406, 664, 407, 801, 133, 223, 339, 297, 143, 801])),
#  ('pathway',
#   'rev_pathway_protein',
#   'gene/protein'): (array([  69, 1663,  208, ..., 1459, 1626, 2475]), array([    0,     0,     1, ..., 27609, 27609, 27609])),
#  ('anatomy',
#   'rev_anatomy_protein_present',
#   'gene/protein'): (array([ 4250, 11792, 12682, ...,  5764,  5878,  6300]), array([22750, 22750, 22750, ..., 19576, 19576, 19576])),
#  ('anatomy',
#   'rev_anatomy_protein_absent',
#   'gene/protein'): (array([ 2599, 10735, 10735, ...,  2230,  5804, 11370]), array([ 9560,  9560, 13132, ...,  4002,  4002,  4002]))}

# %%
output
# Out:
# {'anatomy': 14032.0,
#  'biological_process': 28641.0,
#  'cellular_component': 4175.0,
#  'disease': 17079.0,
#  'drug': 7956.0,
#  'effect/phenotype': 15310.0,
#  'exposure': 817.0,
#  'gene/protein': 27609.0,
#  'molecular_function': 11168.0,
#  'pathway': 2515.0}

# %%
g = dgl.heterograph(DGL_input, num_nodes_dict={i: int(output[i])+1 for i in output.keys()})

# %%
import torch

node_dict = {}
edge_dict = {}
for ntype in g.ntypes:
    node_dict[ntype] = len(node_dict)
for etype in g.etypes:
    edge_dict[etype] = len(edge_dict)
    g.edges[etype].data['id'] = torch.ones(g.number_of_edges(etype), dtype=torch.long) * edge_dict[etype]

# %%
g.edges[g.etypes[2]].data['id']
# Out:
# tensor([2, 2, 2,  ..., 2, 2, 2])

# %%
from dataset_construction import TxData

TxData = TxData(data_folder_path = '/data/pj20/txgnn/kg/')
TxData.prepare_split(split = 'full_graph', seed = 42, no_kg = False)
# Out:
# Found local copy...
# Found local copy...
# Found local copy...
# Found saved processed KG... Loading...
# Splits detected... Loading splits....
# Creating DGL graph....
# Done!

# %%
from txgnn import TxGNN

TxGNN = TxGNN(data = TxData, 
              weight_bias_track = False,
              proj_name = 'TxGNN',
              exp_name = 'TxGNN'
              )

# %%
TxGNN.model_initialize(n_hid = 100, 
                      n_inp = 100, 
                      n_out = 100, 
                      proto = True,
                      proto_num = 3,
                      attention = False,
                      sim_measure = 'all_nodes_profile',
                      bert_measure = 'disease_name',
                      agg_measure = 'rarity',
                      num_walks = 200,
                      walk_mode = 'bit',
                      path_length = 2)

# %%
edge_dict[g.etypes[1]]
# Out:
# 1
